# %% [markdown]
# # Basic Residue - Machine Learning Models for Regression Analysis
#
# This notebook demonstrates the application of machine learning techniques to analyze and predict values from different datasets under the Basic Residue project. The primary objective of this analysis is to evaluate the performance of linear regression models trained on various datasets and compare the models' ability to predict the target variable based on the actual observed values. The datasets used include:
#
# - `dataset_high_scatter`
# - `dataset_low_scatter`
# - `dataset_negative_deviation`
# - `dataset_positive_deviation`
#
# For each dataset, the following steps are performed:
#
# 1. **Data Preprocessing**: Loading datasets, checking for missing values, and reviewing the data structure.
# 2. **Model Training**: Linear regression models are trained to predict the relationship between the target variable ("Predicted") and the feature ("Actual").
# 3. **Model Evaluation**: Performance is evaluated using metrics like Mean Absolute Error (MAE), Mean Squared Error (MSE), and R-squared (R²).
# 4. **Visualization**: Predicted vs Actual values, and residuals (Predicted - Actual) are plotted for each dataset to visually evaluate model performance.
#
# ---
#
# ## Datasets Source:
#
# The datasets used in this project are part of the *Machine Learning for Undergraduate Chemistry* initiative, developed by Professor Darin Ulness. These datasets are from the *ChemAIstry* project, which provides a suite of interactive lab programs to explore machine learning applications in chemistry education.
#
# For more information and to access the datasets, visit the official website of Professor Darin Ulness or the (https://www.darinulness.com/teaching/machine-learning-for-undergraduate-chemistry).
#
# ---
#
# ## Project Goals:
#
# The goal of this project is to build regression models using basic machine learning techniques, evaluate their performance, and analyze the results across various datasets with different types of data scatter and deviation.

# %% [markdown]
# ***Section for dataset_high_scatter.***

# %%
#imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
#load the dataset_high_scatter
dataset_high_scatter = pd.read_csv('drive/MyDrive/Chem_ML_projects/BasicResidue/dataset_high_scatter.csv')

# %%
#Display first 5rows of the dataset
print("First 5 rows of dataset_high_scatter.csv:")
print(dataset_high_scatter.head())
# Out:
# First 5 rows of dataset_high_scatter.csv:
#        Actual   Predicted
# 0   59.308317   76.798659
# 1  142.853574  129.858270
# 2  111.139122   87.075104
# 3   91.805480   70.964592
# 4   27.622703   17.878644

# %% [markdown]
# ***Data Cleaning:***

# %%
#check for missing values and errors
print("Missing values in dataset_high_scatter.csv:")
print(dataset_high_scatter.isnull().sum())
# Out:
# Missing values in dataset_high_scatter.csv:
# Actual       0
# Predicted    0
# dtype: int64

# %% [markdown]
# ***Visualization:***
#
# 1.Predicted vs Actual values plot.
#
# 2.Residuals plot (Difference between predicted and actual values).

# %%
# Plot Predicted vs Actual
plt.figure(figsize=(10, 6))
plt.scatter(dataset_high_scatter['Actual'], dataset_high_scatter['Predicted'], alpha=0.5, color='blue')
plt.plot([dataset_high_scatter['Actual'].min(), dataset_high_scatter['Actual'].max()],
         [dataset_high_scatter['Actual'].min(), dataset_high_scatter['Actual'].max()],
         color='red', linestyle='--')  # 45-degree line
plt.title("Predicted vs Actual Values")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# Calculate residuals (Predicted - Actual)
residuals = dataset_high_scatter['Predicted'] - dataset_high_scatter['Actual']

# Plot Residuals
plt.figure(figsize=(10, 6))
plt.scatter(dataset_high_scatter['Actual'], residuals, alpha=0.5, color='green')
plt.axhline(0, color='red', linestyle='--')  # Zero line
plt.title("Residuals (Predicted - Actual)")
plt.xlabel("Actual")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# ***Model Training:***

# %%
X = dataset_high_scatter[['Actual']].values  # Features
y = dataset_high_scatter['Predicted'].values  # Target variable

# %%
#We’ll use Linear Regression as an example since this is a regression problem.
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#predict using the model
y_pred = model.predict(X)

# %% [markdown]
# ***Calculate Evaluation metrics.***

# %%
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print the evaluation metrics
print(f"Model Mean Absolute Error (MAE): {mae:.2f}")
print(f"Model Mean Squared Error (MSE): {mse:.2f}")
print(f"Model R-squared (R²): {r2:.2f}")
# Out:
# Model Mean Absolute Error (MAE): 16.60
# Model Mean Squared Error (MSE): 429.84
# Model R-squared (R²): 0.80

# %% [markdown]
# ***Section for dataset_low_scatter:***

# %%
# Load the dataset
dataset_low_scatter = pd.read_csv('drive/MyDrive/Chem_ML_projects/BasicResidue/dataset_low_scatter.csv')
print("First 5 rows of dataset_low_scatter:")
print(dataset_low_scatter.head())
# Out:
# First 5 rows of dataset_low_scatter:
#        Actual   Predicted
# 0   59.308317   58.556715
# 1  142.853574  141.220093
# 2  111.139122  105.926233
# 3   91.805480   85.944311
# 4   27.622703   29.944552

# %%
# check for missing values and errors
print("Missing values in dataset_low_scatter.csv:")
print(dataset_low_scatter.isnull().sum())
# Out:
# Missing values in dataset_low_scatter.csv:
# Actual       0
# Predicted    0
# dtype: int64

# %% [markdown]
# ***Model Training.***

# %%
# Define features (X) and target (y)
X = dataset_low_scatter[['Actual']]  # Feature (Actual values)
y = dataset_low_scatter['Predicted']  # Target (Predicted values)

# Initialize and train the model (using Linear Regression as an example)
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Evaluate the model
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print evaluation results
print(f"Model Mean Absolute Error (MAE): {mae:.2f}")
print(f"Model Mean Squared Error (MSE): {mse:.2f}")
print(f"Model R-squared (R²): {r2:.2f}")
# Out:
# Model Mean Absolute Error (MAE): 3.92
# Model Mean Squared Error (MSE): 24.03
# Model R-squared (R²): 0.99

# %%
# Plot Predicted vs Actual
plt.figure(figsize=(10, 6))
plt.scatter(dataset_low_scatter['Actual'], dataset_low_scatter['Predicted'], alpha=0.5, color='blue')
plt.plot([dataset_low_scatter['Actual'].min(), dataset_low_scatter['Actual'].max()],
         [dataset_low_scatter['Actual'].min(), dataset_low_scatter['Actual'].max()], color='red', linestyle='--')  # 45-degree line
plt.title("Predicted vs Actual Values (Low Scatter)")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# Calculate residuals (Predicted - Actual)
residuals_low = dataset_low_scatter['Predicted'] - dataset_low_scatter['Actual']

# Plot Residuals
plt.figure(figsize=(10, 6))
plt.scatter(dataset_low_scatter['Actual'], residuals_low, alpha=0.5, color='green')
plt.axhline(0, color='red', linestyle='--')  # Zero line
plt.title("Residuals (Predicted - Actual) (Low Scatter)")
plt.xlabel("Actual")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# ***Section for Negative Deviation dataset.***

# %%
# Load the Negative Deviation dataset
dataset_negative_deviation = pd.read_csv('drive/MyDrive/Chem_ML_projects/BasicResidue/dataset_negative_deviation.csv')

# Display the first few rows of the dataset
print("First 5 rows of Negative Deviation Dataset:")
print(dataset_negative_deviation.head())
# Out:
# First 5 rows of Negative Deviation Dataset:
#        Actual   Predicted
# 0   59.308317   54.265991
# 1  142.853574  121.891495
# 2  111.139122  101.926199
# 3   91.805480   85.677861
# 4   27.622703   27.659385

# %% [markdown]
# ***Data Cleaning:***

# %%
#check for missing values
print("Missing values in Negative Deviation Dataset:")
print(dataset_negative_deviation.isnull().sum())
# Out:
# Missing values in Negative Deviation Dataset:
# Actual       0
# Predicted    0
# dtype: int64

# %% [markdown]
# ***Model training:***

# %%
# Define features (X) and target (y)
X = dataset_negative_deviation[['Actual']]  # Feature (Actual values)
y = dataset_negative_deviation['Predicted']  # Target (Predicted values)

# Initialize and train the model (using Linear Regression as an example)
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Evaluate the model
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print evaluation results
print(f"Model Mean Absolute Error (MAE): {mae:.2f}")
print(f"Model Mean Squared Error (MSE): {mse:.2f}")
print(f"Model R-squared (R²): {r2:.2f}")
# Out:
# Model Mean Absolute Error (MAE): 3.93
# Model Mean Squared Error (MSE): 24.23
# Model R-squared (R²): 0.98

# %% [markdown]
# ***Visualization.***

# %%
# Plot Predicted vs Actual
plt.figure(figsize=(10, 6))
plt.scatter(dataset_negative_deviation['Actual'], dataset_negative_deviation['Predicted'], alpha=0.5, color='blue')
plt.plot([dataset_negative_deviation['Actual'].min(), dataset_negative_deviation['Actual'].max()],
         [dataset_negative_deviation['Actual'].min(), dataset_negative_deviation['Actual'].max()], color='red', linestyle='--')  # 45-degree line
plt.title("Predicted vs Actual Values (Negative Deviation Dataset)")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# Calculate residuals (Predicted - Actual)
residuals = dataset_negative_deviation['Predicted'] - dataset_negative_deviation['Actual']

# Plot Residuals
plt.figure(figsize=(10, 6))
plt.scatter(dataset_negative_deviation['Actual'], residuals, alpha=0.5, color='green')
plt.axhline(0, color='red', linestyle='--')  # Zero line
plt.title("Residuals (Predicted - Actual) (Negative Deviation Dataset)")
plt.xlabel("Actual")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# ***Section for dataset_positive_deviation.***

# %%
# Load the Positive Deviation dataset
dataset_positive_deviation = pd.read_csv('drive/MyDrive/Chem_ML_projects/BasicResidue/dataset_positive_deviation.csv')

# Display the first few rows of the dataset
print("First 5 rows of Positive Deviation Dataset:")
print(dataset_positive_deviation.head())
# Out:
# First 5 rows of Positive Deviation Dataset:
#        Actual   Predicted
# 0   59.308317   58.207562
# 1  142.853574  156.723404
# 2  111.139122  114.729432
# 3   91.805480  104.786308
# 4   27.622703   30.797172

# %%
#check for missing values
print("Missing values in Positive Deviation Dataset:")
print(dataset_positive_deviation.isnull().sum())
# Out:
# Missing values in Positive Deviation Dataset:
# Actual       0
# Predicted    0
# dtype: int64

# %% [markdown]
# ***Model Training:***

# %%
# Define features (X) and target (y)
X = dataset_positive_deviation[['Actual']]  # Feature (Actual values)
y = dataset_positive_deviation['Predicted']  # Target (Predicted values)

# Initialize and train the model (using Linear Regression as an example)
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# Evaluate the model
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# Print evaluation results
print(f"Model Mean Absolute Error (MAE): {mae:.2f}")
print(f"Model Mean Squared Error (MSE): {mse:.2f}")
print(f"Model R-squared (R²): {r2:.2f}")
# Out:
# Model Mean Absolute Error (MAE): 3.87
# Model Mean Squared Error (MSE): 23.41
# Model R-squared (R²): 0.99

# %% [markdown]
# ***Visualization:***

# %%
# Plot Predicted vs Actual
plt.figure(figsize=(10, 6))
plt.scatter(dataset_positive_deviation['Actual'], dataset_positive_deviation['Predicted'], alpha=0.5, color='blue')
plt.plot([dataset_positive_deviation['Actual'].min(), dataset_positive_deviation['Actual'].max()],
         [dataset_positive_deviation['Actual'].min(), dataset_positive_deviation['Actual'].max()],
         color='red', linestyle='--')  # 45-degree line
plt.title("Predicted vs Actual Values for Positive Deviation")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()


# Calculate residuals (Predicted - Actual)
residuals = dataset_positive_deviation['Predicted'] - dataset_positive_deviation['Actual']

# Plot Residuals
plt.figure(figsize=(10, 6))
plt.scatter(dataset_positive_deviation['Actual'], residuals, alpha=0.5, color='green')
plt.axhline(0, color='red', linestyle='--')  # Zero line
plt.title("Residuals (Predicted - Actual) for Positive Deviation")
plt.xlabel("Actual")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# ***Conclusion:***

# %% [markdown]
# Model Comparison Across Datasets:
# 1. High Scatter Dataset:
#
# MAE: 16.60
# MSE: 429.84
# R²: 0.80
# The High Scatter Dataset shows a moderate R² value of 0.80, indicating that the model explains 80% of the variance in the data. The MAE and MSE values are relatively high, indicating that the model's predictions are off by a significant amount on average. The Predicted vs Actual scatter plot shows considerable deviation from the 45-degree line, while the residuals plot suggests that the model struggles to capture some patterns, especially for extreme values.
#
# 2. Low Scatter Dataset:
#
# MAE: 3.92
# MSE: 24.03
# R²: 0.99
# The Low Scatter Dataset exhibits excellent model performance with an R² of 0.99, meaning the model can explain almost all of the variance in the data. The MAE and MSE values are very low, suggesting that the predicted values are close to the actual values on average. The Predicted vs Actual plot aligns well with the red 45-degree line, and the residuals plot shows no significant patterns, which implies the model is a good fit for this dataset.
#
# 3. Negative Deviation Dataset:
#
# MAE: 3.93
# MSE: 24.23
# R²: 0.98
# The Negative Deviation Dataset also demonstrates good model performance with an R² of 0.98. The MAE and MSE values are similar to the Low Scatter Dataset, indicating that the model's predictions are accurate. However, the Predicted vs Actual plot suggests that the model's predictions are systematically lower than the actual values, resulting in a consistent negative deviation, as seen in the residuals plot.
#
# 4. Positive Deviation Dataset:
#
# MAE: 3.87
# MSE: 23.41
# R²: 0.99
# Similar to the Negative Deviation Dataset, the Positive Deviation Dataset exhibits excellent performance with an R² of 0.99. The MAE and MSE are again low, indicating that the model is accurate in its predictions. The Predicted vs Actual plot suggests a consistent overestimation of the predicted values, as seen in the positive residuals, but the model still performs well overall.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/Smartlyfe21/Basic_Residue_Analysis_ML.git
# Out:
# Cloning into 'Basic_Residue_Analysis_ML'...
# ...

# %%
# %cd Basic_Residue_Analysis_ML
# Out:
# /content/Basic_Residue_Analysis_ML

# %%
# !ls /content/
# Out:
# Basic_Residue_Analysis_ML  drive  sample_data

# %%
# !find /content/ -name "*.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled3.ipynb
# /content/drive/MyDrive/Colab Notebooks/dog-vision (3).ipynb
# /content/drive/MyDrive/Colab Notebooks/dog-vision (2).ipynb
# /content/drive/MyDrive/Colab Notebooks/dog-vision (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/dog-vision.ipynb
# /content/drive/MyDrive/Colab Notebooks/Sustainable_energy_and_environmental-data.ipynb
# /content/drive/MyDrive/Colab Notebooks/S_Energy_Prediction.ipynb
# /content/drive/MyDrive/Colab Notebooks/Copy of Basic-residual.ipynb
# /content/drive/MyDrive/Colab Notebooks/Basic_Residue_Regression_Analysis.ipynb
# /content/drive/MyDrive/Colab Notebooks/Copy of Basic_Residue_Regression_Analysis.ipynb
